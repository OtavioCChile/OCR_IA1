# %% [markdown]
# <a href="https://colab.research.google.com/github/OtavioCChile/OCR_IA1/blob/main/IMGREC_OCR_Tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# !sudo apt-get install -y tesseract-ocr-por
# !pip install pillow
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-por
# 0 upgraded, 1 newly installed, 0 to remove and 1 not upgraded.
# Need to get 856 kB of archives.
# After this operation, 1,998 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-por all 1:4.00~git30-7274cfa-1.1 [856 kB]
# Fetched 856 kB in 0s (10.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# ...

# %%
# !tesseract --list-langs
# Out:
# List of available languages (3):
# eng
# osd
# por

# %%
# Importar bibliotecas necessárias
import pytesseract
from PIL import Image
import requests
from io import BytesIO

# imagem de exemplo
for i in range(7):
  img = f'/content/{i}.jpg'
  # Executar OCR na imagem
  texto = pytesseract.image_to_string(img, lang='por')
  print(f"Imagem {i}: {texto}")
# Out:
# Imagem 0: NENHUM |
# MEIA:
# Tp
# MUS SNIS
#
# Imagem 1: OS IR
# DN
# UEL
#
# Imagem 2: NÃo SOU
# CARTÃO DE
# CRÉDITO PRA
# TER LIMITE
#
# PosT= MT
# DIA
#
# Imagem 3:
#
# HOJE NÃO TEM
# FRASE
# MOTIVACIONAL!
# TOME SEU CAFÉ
# SE VIRA, DÊ
#
# SEUS PULOS
# METE O LOUCO.
#
# Imagem 4: IIS CR sisjo pe)
# ESTIVERAM TÃO
# DISCENTE
# REDES SOCIAIS E,
# AOS MESMO TEMPO,
#
# - TÃO DISTANTES DE
# SI MESMAS. EIS A
# ERA DA SOLIDÃO.
#
# Etr
#
#
#
# Imagem 5:
#
#
# TRANSFORMA
# ”
#
# Imagem 6: NUNCA FOISORTE,
# TUDO QUE CONQUISTEI
# FOIPASSANDO RAIVA.
